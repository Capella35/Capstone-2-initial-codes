# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import quandl

# %%
#Renewable energy production, other than fuel ethanol, Texas:Billion Btu
ROPRB_P=quandl.get('EIA/SEDS_ROPRB_TX_A', authtoken="kpJ55znwmJaDKorhyGub")
#Renewable energy production, Texas::Billion Btu
REPRB_P=quandl.get('EIA/SEDS_REPRB_TX_A', authtoken="kpJ55znwmJaDKorhyGub")
#Fuel ethanol production, including denaturant, Texas::Thousand barrels
ENPRP_P=quandl.get('EIA/SEDS_ENPRP_TX_A', authtoken="kpJ55znwmJaDKorhyGub")
#1.Coal production, Texas::Billion Btu
CLPRP_P= quandl.get('EIA/SEDS_CLPRP_TX_A', authtoken="kpJ55znwmJaDKorhyGub")
#2.Crude oil production (including lease condensate), Texas::Thousand barrels
PAPRP_P=quandl.get('EIA/SEDS_PAPRP_TX_A', authtoken="kpJ55znwmJaDKorhyGub")
#3.Nuclear electricity, total net generation, Texas::Million kilowatthours
NUETP_G=quandl.get('EIA/SEDS_NUETP_TX_A', authtoken="kpJ55znwmJaDKorhyGub")
#4.Nuclear electric power consumed, Texas::Billion Btu
NUETB_C=quandl.get ('EIA/SEDS_NUETB_TX_A', authtoken="kpJ55znwmJaDKorhyGub")
#5.Natural gas marketed production, Texas::Billion Btu
NGMPB_P=quandl.get('EIA/SEDS_NGMPB_TX_A', authtoken="kpJ55znwmJaDKorhyGub")
#6.Geothermal and solar energy consumed in the residential sector, Texas::Billion Btu
GORCB_C=quandl.get('EIA/SEDS_GORCB_TX_A', authtoken="kpJ55znwmJaDKorhyGub")
#7.Wood consumed in the residential sector at a cost, Texas::Billion Btu
WDRSB_C=quandl.get('EIA/SEDS_WDRSB_TX_A', authtoken="kpJ55znwmJaDKorhyGub")
#8.Geothermal energy and hydroelectricity consumed in the commercial sector, Texas::Billion Btu
GOCCB_C=quandl.get('EIA/SEDS_GOCCB_TX_A', authtoken="kpJ55znwmJaDKorhyGub")
#9.Supplemental gaseous fuels consumed by the commercial sector, Texas::Billion Btu
SFCCB_C=quandl.get('EIA/SEDS_SFCCB_TX_A', authtoken="kpJ55znwmJaDKorhyGub")
#10.Wood and waste consumed in the commercial sector at a cost, Texas::Billion Btu
WWCSB_C=quandl.get('EIA/SEDS_WWCSB_TX_A', authtoken="kpJ55znwmJaDKorhyGub")
#11.Wood and waste consumed in the commercial sector at no cost, Texas::Billion Btu
WWCXB_C=quandl.get('EIA/SEDS_WWCXB_TX_A', authtoken="kpJ55znwmJaDKorhyGub")
#12.Electricity consumed by refineries, Texas::Billion Btu
ESRFB_C=quandl.get('EIA/SEDS_ESRFB_TX_A', authtoken="kpJ55znwmJaDKorhyGub")
#13.Total primary energy and electricity consumed, Texas::Billion Btu
TNSCB_C=quandl.get('EIA/SEDS_TNSCB_TX_A', authtoken="kpJ55znwmJaDKorhyGub")
#14.LPG consumed as refinery fuel, Texas::Billion Btu
LGRFB_C= quandl.get('EIA/SEDS_LGRFB_TX_A', authtoken="kpJ55znwmJaDKorhyGub")
#Total energy consumption per capita in the residential sector, Texas::Million Btu
TERPB_C= quandl.get('EIA/SEDS_TERPB_TX_A', authtoken="kpJ55znwmJaDKorhyGub")
#Total energy consumption per capita in the commercial sector, Texas::Million Btu
TECPB_C= quandl.get('EIA/SEDS_TECPB_TX_A', authtoken="kpJ55znwmJaDKorhyGub")
#Total energy consumption per capita in the industrial sector, Texas::Million Btu
TEIPB_C=quandl.get('EIA/SEDS_TEIPB_TX_A', authtoken="kpJ55znwmJaDKorhyGub")
#Total energy consumption per capita in the transportation sector, Texas::Million Btu
TEAPB_C=quandl.get('EIA/SEDS_TEAPB_TX_A', authtoken="kpJ55znwmJaDKorhyGub")
#Total energy consumption per capita, Texas::Million Btu
TETPB_C= quandl.get('EIA/SEDS_TETPB_TX_A', authtoken="kpJ55znwmJaDKorhyGub")

df= pd.concat([ROPRB_P,REPRB_P,ENPRP_P, CLPRP_P, PAPRP_P ,NUETP_G,NGMPB_P,GORCB_C,WDRSB_C,GOCCB_C,SFCCB_C, WWCSB_C,WWCXB_C,ESRFB_C, TNSCB_C,LGRFB_C,TERPB_C,TECPB_C, TEIPB_C, TEAPB_C,TETPB_C], axis=1, join='outer', join_axes=None, ignore_index=True,)
df.columns = ['ROPRB_P','REPRB_P','ENPRP_P', 'CLPRP_P', 'PAPRP_P' ,'NUETP_G','NGMPB_P','GORCB_C','WDRSB_C','GOCCB_C','SFCCB_C', 'WWCSB_C', 'WWCXB_C', 'ESRFB_C', 'TNSCB_C','LGRFB_C','TERPB_C','TECPB_C', 'TEIPB_C', 'TEAPB_C','TETPB_C']          
df
# Out:
#              ROPRB_P   REPRB_P  ENPRP_P  CLPRP_P    PAPRP_P  NUETP_G  \
# Date
# 1960-12-31   50155.0   50155.0      0.0   2098.0   927479.0      0.0
# 1961-12-31   52023.0   52023.0      0.0   2108.0   939191.0      0.0
# 1962-12-31   47721.0   47721.0      0.0   2054.0   943323.0      0.0
# 1963-12-31   42718.0   42718.0      0.0   2180.0   977782.0      0.0
# 1964-12-31   43884.0   43884.0      0.0   2291.0   989520.0      0.0
# 1965-12-31   48967.0   48967.0      0.0   2411.0  1000743.0      0.0
# 1966-12-31   51980.0   51980.0      0.0   2253.0  1056499.0      0.0
# 1967-12-31   49944.0   49944.0      0.0   2153.0  1117319.0      0.0
# 1968-12-31   62939.0   62939.0      0.0   2291.0  1130276.0      0.0
# 1969-12-31   64351.0   64351.0      0.0   2249.0  1148991.0      0.0
# 1970-12-31   62757.0   62757.0      0.0   2310.0  1247486.0      0.0
# 1971-12-31   60471.0   60471.0      0.0   2253.0  1221211.0      0.0
# ...

# %%
#DF.fillna(method = 'bfill', axis=0).fillna("0.0")

# %%
df.shape
# Out:
# (57, 21)

# %%
def ShowMissing(df):
    num_missing = df.isnull().sum().sort_values(ascending=False)
    missing_percent = (100*df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
    missing_num_percent = pd.concat([num_missing, missing_percent], axis=1, 
                                    keys=['num_missing', 'missing_percent'])
    return missing_num_percent

# %%
missing_num = ShowMissing(df)
missing_num
# Out:
#          num_missing  missing_percent
# SFCCB_C           20        35.087719
# GOCCB_C           16        28.070175
# GORCB_C           16        28.070175
# LGRFB_C           11        19.298246
# TNSCB_C           11        19.298246
# WWCXB_C           11        19.298246
# WWCSB_C           11        19.298246
# WDRSB_C           11        19.298246
# ESRFB_C           10        17.543860
# NGMPB_P            1         1.754386
# REPRB_P            1         1.754386
# ENPRP_P            1         1.754386
# CLPRP_P            1         1.754386
# PAPRP_P            1         1.754386
# TETPB_C            1         1.754386
# TEAPB_C            1         1.754386
# TERPB_C            1         1.754386
# TECPB_C            1         1.754386
# TEIPB_C            1         1.754386
# ROPRB_P            1         1.754386
# NUETP_G            0         0.000000

# %%
missing_cols=['SFCCB_C','GOCCB_C','GORCB_C','LGRFB_C','TNSCB_C',
              'WWCXB_C','WWCSB_C','WDRSB_C','ESRFB_C','NGMPB_P',
             'REPRB_P','ENPRP_P','CLPRP_P','PAPRP_P','TETPB_C','TEAPB_C',
             'TERPB_C','TECPB_C','TEIPB_C','ROPRB_P']

# %%
df[missing_cols].head(3)
# Out:
#             SFCCB_C  GOCCB_C  GORCB_C  LGRFB_C  TNSCB_C  WWCXB_C  WWCSB_C  \
# Date
# 1960-12-31      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1961-12-31      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1962-12-31      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#             WDRSB_C  ESRFB_C    NGMPB_P  REPRB_P  ENPRP_P  CLPRP_P   PAPRP_P  \
# Date
# 1960-12-31      NaN      NaN  6619864.0  50155.0      0.0   2098.0  927479.0
# 1961-12-31      NaN      NaN  6699514.0  52023.0      0.0   2108.0  939191.0
# 1962-12-31      NaN      NaN  6830501.0  47721.0      0.0   2054.0  943323.0
#
#             TETPB_C  TEAPB_C  TERPB_C  TECPB_C  TEIPB_C  ROPRB_P
# Date
# 1960-12-31    461.0     83.0     38.0     21.0    320.0  50155.0
# 1961-12-31    455.0     83.0     36.0     21.0    315.0  52023.0
# 1962-12-31    464.0     83.0     41.0     22.0    317.0  47721.0

# %%
for item in missing_cols:
    df[item].fillna(df[item].mean(), inplace = True)

# %%
missing_num = ShowMissing(df)
missing_num.head(5)
# Out:
#          num_missing  missing_percent
# TETPB_C            0              0.0
# GOCCB_C            0              0.0
# REPRB_P            0              0.0
# ENPRP_P            0              0.0
# CLPRP_P            0              0.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from scipy.stats import norm, skew

# %%
df.describe()
# Out:
#              ROPRB_P        REPRB_P      ENPRP_P       CLPRP_P       PAPRP_P  \
# count      57.000000      57.000000    57.000000     57.000000  5.700000e+01
# mean   134478.607143  139808.678571   931.053571  32032.839286  8.129030e+05
# std    114082.598532  126984.346771  2367.540959  20161.239536  2.977169e+05
# min     42718.000000   42718.000000     0.000000   2054.000000  3.912700e+05
# 25%     70512.000000   70520.000000     0.000000   7684.000000  5.365840e+05
# 50%     96535.000000   96535.000000     0.000000  40982.000000  8.692180e+05
# 75%    122666.000000  122666.000000     9.000000  48590.000000  1.056499e+06
# max    522387.000000  573323.000000  8988.000000  55755.000000  1.299926e+06
#
#             NUETP_G       NGMPB_P      GORCB_C       WDRSB_C     GOCCB_C  \
# count     57.000000  5.700000e+01    57.000000     57.000000   57.000000
# mean   16950.087719  7.067048e+06   575.243902   5779.108696  159.878049
# ...

# %%
sns.heatmap(df.corr())

# %%
num_bins = 5


fig, axes = plt.subplots(nrows=4, ncols=1, figsize=(10,10))
ax0, ax1, ax2, ax3 = axes.flatten()

ax0.hist(df['TEAPB_C'], num_bins, alpha=0.99, label=["TEAPB_C"])
ax0.set_title("Total energy consumption per capita in the transportation sector in million BTU (Texas)")

ax1.hist(df['TERPB_C'], num_bins, alpha=0.99, label=["TERPB_C"])
ax1.set_title("Total energy consumption per capita in the residential sector,in million BTU (Texas)")

ax2.hist(df['TERPB_C'], num_bins, alpha=0.99, label=["TERPB_C"])
ax2.set_title("Total energy consumption per capita in the commercial sector, in million BTU (Texas)")

ax3.hist(df['TEIPB_C'], num_bins, alpha=0.99, label=["TEIPB_C"])
ax3.set_title("Total energy consumption per capita in the industrial sector, in million BTU (Texas)")


plt.show()

# %%
plt.subplot(3, 1, 1)
plt.plot(TERPB_C.index,TERPB_C)
plt.xticks(TERPB_C.index[0::3],[])
plt.title('Total energy consumption per capita')
plt.ylabel('residential sector,')
plt.subplot(3, 1, 2)
plt.plot(TECPB_C.index,TECPB_C)
plt.xlabel('year')
plt.ylabel('commercial sector')
plt.subplot(3, 1, 3)
plt.plot(TEIPB_C.index,TEIPB_C)
plt.xlabel('year')
plt.ylabel('industrial sector')
plt.legend();

plt.show()
